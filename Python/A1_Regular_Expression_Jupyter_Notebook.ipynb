# %%
import re

# %%
#Return a list containing every occurrence of "ai":
txt = "The rain in Spain"
x = re.findall("ai", txt)
y=re.findall("in",txt)
print(x)
print(y)
# Out:
# ['ai', 'ai']
# ['in', 'in', 'in']

# %%
txt = "The rain in Spain"
#Check if "Portugal" is in the string:
x = re.findall("ai", txt)
print(x)

if (x):
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['ai', 'ai']
# Yes, there is at least one match!

# %%
#there is more than one match, only the first occurrence of the match will be returned
txt = "The rain in Spain"
x = re.search("\s",txt)
print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %%
txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %%
#Split the string at every white-space character:

txt = "my favorite language is python"
x = re.split("\s", txt)
print(x)
# Out:
# ['my', 'favorite', 'language', 'is', 'python']

# %%
#Split the string at the first white-space character:

txt = "my favorite language is python"
x = re.split("\s", txt,2)
print(x)
# Out:
# ['my', 'favorite', 'language is python']

# %%
#Replace all white-space characters with the digit "9":

txt = "The rain in Spain"
x = re.sub("i", "10", txt)
print(x)
# Out:
# The ra10n 10n Spa10n

# %%
#Replace the first two occurrences of a white-space character with the digit 9:

txt = " This is my first Regular Expression "
x = re.sub("\s", "9", txt,3)
print(x)
# Out:
# 9This9is9my first Regular Expression

# %%
#The search() function returns a Match object:

txt = "The rain in Spain"
x = re.search("in", txt)
print(x)
# Out:
# <re.Match object; span=(6, 8), match='in'>

# %%
#Search for an upper case "S" character in the beginning of a word, and print its position:

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
# (12, 17)

# %%
#The string property returns the search string:

txt = "The rain in Spain"
x = re.search(r"\s", txt)
print(x.string)
# Out:
# The rain in Spain

# %%
#Search for an upper case "S" character in the beginning of a word, and print the word:

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain

# %%
line = "Cats are smarter than dogs"

matchObj = re.match( r'(.*) are (.*?) .*', line, re.M|re.I)

if matchObj:
   print("matchObj.group() : ", matchObj.group())
   print("matchObj.group(1) : ", matchObj.group(1))
   print("matchObj.group(2) : ", matchObj.group(2))

else:
   print("No match!!")
# Out:
# matchObj.group() :  Cats are smarter than dogs
# matchObj.group(1) :  Cats
# matchObj.group(2) :  smarter

# %%
#Email is valid or not
email=input("enter the email id:")
match=re.search(r'([\w\.-]+)@([\w\.-]+)',email)
if match:
    print("Email is Valid")
else:
    print("email is not Valid")
# Out:
# enter the email id:123an@gmail.com
# Email is Valid

# %%
# To search string
pat=['software testing','hello1','world99']
s1='software testing is awsome'
for p1 in pat:
    print('Looking for "%s" in "%s"->' % (p1,s1),end="")
    if re.search(p1,s1):
        print("found match!!!")
    else:
        print("Not found")
# Out:
# Looking for "software testing" in "software testing is awsome"->found match!!!
# Looking for "hello1" in "software testing is awsome"->Not found
# Looking for "world99" in "software testing is awsome"->Not found

# %%
# enter the phone number and email id  print it is valid or not
# Out:
# two -> o
# world -> r
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1f5b3249771e> in <module>()
#       5
#       6 print(t1[3][-1],"->",t1[3][-1][2])
# ----> 7 print(t1[3][-1],"->",t1[3][1][2])
#       8
#       9
#
# TypeError: 'int' object is not subscriptable
